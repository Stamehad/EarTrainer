# %% [markdown]
# ## ALL CURRENT LEVELS

# %%
# %run get_levels.py
# Out:
# 0) PATHWAYS_1_4 | L=1 | bpm=60 | allowed_degrees=[0,1,2,3]
# 1) PATHWAYS_5_7 | L=1 | bpm=60 | allowed_degrees=[4,5,6]
# 2) PATHWAYS | L=1 | bpm=60 | allowed_degrees=[n/a]
# 3) NOTE_1_4 | L=2 | bpm=72 | allowed_degrees=[0,1,2,3]
# 4) NOTE_5_7 | L=2 | bpm=72 | allowed_degrees=[4,5,6]
# 5) NOTE | L=2 | bpm=72 | allowed_degrees=[4,5,6]
# 6) NOTE_TO_TONIC | L=3 | bpm=72 | allowed_degrees=[1,2,3,4,5,6]
# 7) NOTE_AFTER_TONIC | L=3 | bpm=72 | allowed_degrees=[1,2,3,4,5,6]
# 8) NOTE_WITH_TONIC | L=3 | bpm=72 | allowed_degrees=[1,2,3,4,5,6]
