# %%
# Path setup so Python can find the compiled _earcore module and the Python package
import sys, os
from pathlib import Path

def add_paths():
    cwd = Path.cwd()
    # Walk up to locate eartrainer/eartrainer_Cpp/{build,python}
    for base in [cwd, *cwd.parents]:
        build = base / 'eartrainer' / 'eartrainer_Cpp' / 'build'
        py = base / 'eartrainer' / 'eartrainer_Cpp' / 'python'
        added = False
        if build.exists():
            sys.path.insert(0, str(build))
            added = True
        if py.exists():
            sys.path.insert(0, str(py))
            added = True
        if added:
            return build, py
    return None, None

build_path, py_path = add_paths()
print('Using build path:', build_path)
print('Using python path:', py_path)
# Out:
# Using build path: /Users/itamarshamir/Projects/ear_trainer/eartrainer/eartrainer_Cpp/build
# Using python path: /Users/itamarshamir/Projects/ear_trainer/eartrainer/eartrainer_Cpp/python

# %%
import sys
import pathlib

PROJECT_ROOT = pathlib.Path().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from eartrainer.session_engine import SessionEngine
from eartrainer import models

print("SessionEngine ready")
# Out:
# SessionEngine ready

# %%
def run_adaptive_bout(track_levels=None, n_questions=6, seed=7):
    engine = SessionEngine()
    levels = list(track_levels or [])
    spec = models.SessionSpec(
        version="v1",
        drill_kind="adaptive",
        key="",
        #key="C major",
        #range=[48, 72],
        #tempo_bpm=96,
        n_questions=n_questions,
        generation="adaptive",
        #assistance_policy={"Replay": 0},
        sampler_params={"track_levels": levels},
        seed=seed,
        adaptive=True,
        track_levels=levels,
    )
    session_id = engine.create_session(spec)
    summary = None
    timeline = []
    key = engine.session_key(session_id)
    print("Session key:", key)
    prompt = engine.orientation_prompt(session_id)
    print("Orientation prompt:", prompt)


    while True:
        next_item = engine.next_question(session_id)
        if isinstance(next_item, models.SessionSummary):
            summary = next_item
            break

        bundle = next_item
        print(bundle)
        metrics = models.ResultMetrics(rt_ms=1200, attempts=1, question_count=1)
        report = models.ResultReport(
            question_id=bundle.question_id,
            final_answer=bundle.correct_answer,
            correct=True,
            metrics=metrics,
        )
        timeline.append(bundle.question_id)

        next_payload = engine.submit_result(session_id, report)
        if isinstance(next_payload, models.SessionSummary):
            summary = next_payload
            break

    memory = engine.end_session(session_id)
    diagnostics = engine.adaptive_diagnostics(session_id)

    return {
        "session_id": session_id,
        "timeline": timeline,
        "summary": summary,
        "memory": memory,
        "diagnostics": diagnostics,
    }

# %%
import sys, eartrainer
print("exe:", sys.executable)
print("eartrainer location:", eartrainer.__file__)
from eartrainer import SessionEngine
print(hasattr(SessionEngine(), "adaptive_diagnostics"))
# Out:
# exe: /Users/itamarshamir/miniconda3/envs/eartrainer_cpp/bin/python
# eartrainer location: /Users/itamarshamir/Projects/ear_trainer/eartrainer/eartrainer_Cpp/python/eartrainer/__init__.py
# True

# %%
from pprint import pprint

result = run_adaptive_bout(track_levels=[11,111], n_questions=5, seed=42)

print("Session ID:", result["session_id"])
print("Timeline:", result["timeline"])
print("\nSummary totals:")
pprint(result["summary"].totals)

memory = result["memory"]
if memory.adaptive:
    print("\nAdaptive Memory:")
    pprint(
        {
            "bout_average": memory.adaptive.bout_average,
            "level_up": memory.adaptive.level_up,
            "graduate_threshold": memory.adaptive.graduate_threshold,
            "level": memory.adaptive.level.__dict__ if memory.adaptive.level else None,
        }
    )
    print("\nDrill EMAs:")
    for drill_id, drill_info in memory.adaptive.drills.items():
        pprint({drill_id: {"family": drill_info.family, "ema_score": drill_info.ema_score}})
else:
    print("No adaptive data returned.")

print(f"="*60)
print(f"=== ADAPTIVE DIAGNOSTICS")
print(f"="*60)
pprint(result["diagnostics"])
# Out:
# Session key: Bb major
# Orientation prompt: Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=96, length_ticks=2859, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=58, vel=90, control=None, value=None), MidiEvent(t=246, type='note_off', note=58, vel=None, control=None, value=None), MidiEvent(t=246, type='note_on', note=60, vel=90, control=None, value=None), MidiEvent(t=492, type='note_off', note=60, vel=None, control=None, value=None), MidiEvent(t=492, type='note_on', note=62, vel=90, control=None, value=None), MidiEvent(t=738, type='note_off', note=62, vel=None, control=None, value=None), MidiEvent(t=738, type='note_on', note=63, vel=90, control=None, value=None), MidiEvent(t=984, type='note_off', note=63, vel=None, control=None, value=None), MidiEvent(t=984, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=1230, type='note_off', note=65, vel=None, control=None, value=None), MidiEvent(t=1230, type='note_on', note=67, vel=90, control=None, value=None), MidiEvent(t=1476, type='note_off', note=67, vel=None, control=None, value=None), MidiEvent(t=1476, type='note_on', note=69, vel=90, control=None, value=None), MidiEvent(t=1722, type='note_off', note=69, vel=None, control=None, value=None), MidiEvent(t=1722, type='note_on', note=70, vel=90, control=None, value=None), MidiEvent(t=1968, type='note_off', note=70, vel=None, control=None, value=None), MidiEvent(t=1968, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=2214, type='note_off', note=65, vel=None, control=None, value=None), MidiEvent(t=2214, type='note_on', note=62, vel=90, control=None, value=None), MidiEvent(t=2460, type='note_off', note=62, vel=None, control=None, value=None), MidiEvent(t=2460, type='note_on', note=58, vel=90, control=None, value=None), MidiEvent(t=2859, type='note_off', note=58, vel=None, control=None, value=None)])], format='midi-clip/v1'))
# QuestionBundle(question_id='q-001', question=TypedPayload(type='melody', payload={'degrees': [2, 0, -1], 'midi': [64, 60, 60]}), correct_answer=TypedPayload(type='melody_notes', payload={'degrees': [2, 0, -1]}), prompt=Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=90, length_ticks=2160, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=64, vel=90, control=None, value=None), MidiEvent(t=720, type='note_off', note=64, vel=None, control=None, value=None), MidiEvent(t=720, type='note_on', note=60, vel=90, control=None, value=None), MidiEvent(t=1440, type='note_off', note=60, vel=None, control=None, value=None), MidiEvent(t=1440, type='note_on', note=60, vel=90, control=None, value=None), MidiEvent(t=2160, type='note_off', note=60, vel=None, control=None, value=None)])], format='midi-clip/v1')), ui_hints={'allowed_assists': ['Replay', 'TempoDown'], 'answer_kind': 'melody_notes', 'assist_budget': {}})
# QuestionBundle(question_id='q-002', question=TypedPayload(type='melody', payload={'degrees': [2, 3, 4], 'midi': [64, 65, 67]}), correct_answer=TypedPayload(type='melody_notes', payload={'degrees': [2, 3, 4]}), prompt=Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=90, length_ticks=2160, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=64, vel=90, control=None, value=None), MidiEvent(t=720, type='note_off', note=64, vel=None, control=None, value=None), MidiEvent(t=720, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=1440, type='note_off', note=65, vel=None, control=None, value=None), MidiEvent(t=1440, type='note_on', note=67, vel=90, control=None, value=None), MidiEvent(t=2160, type='note_off', note=67, vel=None, control=None, value=None)])], format='midi-clip/v1')), ui_hints={'allowed_assists': ['Replay', 'TempoDown'], 'answer_kind': 'melody_notes', 'assist_budget': {}})
# QuestionBundle(question_id='q-003', question=TypedPayload(type='melody', payload={'degrees': [3, 2, 3], 'midi': [65, 64, 65]}), correct_answer=TypedPayload(type='melody_notes', payload={'degrees': [3, 2, 3]}), prompt=Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=90, length_ticks=2160, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=720, type='note_off', note=65, vel=None, control=None, value=None), MidiEvent(t=720, type='note_on', note=64, vel=90, control=None, value=None), MidiEvent(t=1440, type='note_off', note=64, vel=None, control=None, value=None), MidiEvent(t=1440, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=2160, type='note_off', note=65, vel=None, control=None, value=None)])], format='midi-clip/v1')), ui_hints={'allowed_assists': ['Replay', 'TempoDown'], 'answer_kind': 'melody_notes', 'assist_budget': {}})
# QuestionBundle(question_id='q-004', question=TypedPayload(type='melody', payload={'degrees': [4, 3, 0], 'midi': [67, 65, 60]}), correct_answer=TypedPayload(type='melody_notes', payload={'degrees': [4, 3, 0]}), prompt=Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=90, length_ticks=2160, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=67, vel=90, control=None, value=None), MidiEvent(t=720, type='note_off', note=67, vel=None, control=None, value=None), MidiEvent(t=720, type='note_on', note=65, vel=90, control=None, value=None), MidiEvent(t=1440, type='note_off', note=65, vel=None, control=None, value=None), MidiEvent(t=1440, type='note_on', note=60, vel=90, control=None, value=None), MidiEvent(t=2160, type='note_off', note=60, vel=None, control=None, value=None)])], format='midi-clip/v1')), ui_hints={'allowed_assists': ['Replay', 'TempoDown'], 'answer_kind': 'melody_notes', 'assist_budget': {}})
# QuestionBundle(question_id='q-005', question=TypedPayload(type='melody', payload={'degrees': [0, -1, -2], 'midi': [72, 71, 69]}), correct_answer=TypedPayload(type='melody_notes', payload={'degrees': [0, -1, -2]}), prompt=Prompt(modality='midi-clip', midi_clip=MidiClip(ppq=480, tempo_bpm=90, length_ticks=2160, tracks=[MidiTrack(name='prompt', channel=0, program=0, events=[MidiEvent(t=0, type='note_on', note=72, vel=90, control=None, value=None), MidiEvent(t=720, type='note_off', note=72, vel=None, control=None, value=None), MidiEvent(t=720, type='note_on', note=71, vel=90, control=None, value=None), MidiEvent(t=1440, type='note_off', note=71, vel=None, control=None, value=None), MidiEvent(t=1440, type='note_on', note=69, vel=90, control=None, value=None), MidiEvent(t=2160, type='note_off', note=69, vel=None, control=None, value=None)])], format='midi-clip/v1')), ui_hints={'allowed_assists': ['Replay', 'TempoDown'], 'answer_kind': 'melody_notes', 'assist_budget': {}})
# Session ID: sess-1
# Timeline: ['q-001', 'q-002', 'q-003', 'q-004', 'q-005']
#
# Summary totals:
# {'adaptive_bout_score': 0.9924999999999999,
#  'adaptive_drill_score_map': {'MELODY60': {'ema_score': None,
#                                            'family': 'melody'},
#                               'MELODY60_STEP1': {'ema_score': 0.9925,
#                                                  'family': 'melody'},
#                               'MELODY60_STEP2': {'ema_score': 0.9924999999999999,
#                                                  'family': 'melody'}},
#  'adaptive_drill_scores': [0.9925, 0.9924999999999999, None],
#  'adaptive_level_current': 111,
#  'adaptive_level_suggested': 112,
#  'adaptive_level_track': 'melody_levels',
#  'adaptive_level_up': True,
#  'adaptive_level_up_threshold': 0.8,
#  'avg_rt_ms': 1200,
#  'correct': 5,
#  'incorrect': 0}
#
# Adaptive Memory:
# {'bout_average': 0.9924999999999999,
#  'graduate_threshold': 0.8,
#  'level': {'current_level': 111,
#            'suggested_level': 112,
#            'track_index': 1,
#            'track_name': 'melody_levels'},
#  'level_up': True}
#
# Drill EMAs:
# {'MELODY60': {'ema_score': None, 'family': 'melody'}}
# {'MELODY60_STEP1': {'ema_score': 0.9925, 'family': 'melody'}}
# {'MELODY60_STEP2': {'ema_score': 0.9924999999999999, 'family': 'melody'}}
# ============================================================
# === ADAPTIVE DIAGNOSTICS
# ============================================================
# {'bout_score_average': 0.9924999999999999,
#  'catalog_mode': 'builtin',
#  'current_track': 'melody_levels',
#  'drill_scores': [0.9925, 0.9924999999999999, None],
#  'families': ['melody', 'melody', 'melody'],
#  'ids': ['MELODY60_STEP1', 'MELODY60_STEP2', 'MELODY60'],
#  'last_pick': 0,
#  'last_track_pick': 1,
#  'level': 111,
#  'level_current': 111,
#  'level_suggested': 112,
#  'level_track_index': 1,
#  'level_track_name': 'melody_levels',
#  'level_up_ready': True,
#  'level_up_threshold': 0.8,
#  'phase_consistent': True,
#  'phase_digit': 1,
#  'pick_counts': [4, 1, 0],
#  'questions_emitted': 5,
#  'resources_dir': '/Users/itamarshamir/Projects/ear_trainer/eartrainer/eartrainer_Cpp/resources',
#  'slots': 3,
#  'track_levels': [11, 111],
#  'track_weights': [1, 3],
#  'tracks': [{'current_level': 11,
#              'levels_in_scope': [11],
#              'name': 'degree_levels',
#              'weight': 1},
#             {'current_level': 111,
#              'levels_in_scope': [111, 112, 113],
#              'name': 'melody_levels',
#              'weight': 3}]}

# %%
result['summary'].totals
# Out:
# {'adaptive_bout_score': 0.9924999999999999,
#  'adaptive_drill_score_map': {'MELODY60': {'ema_score': None,
#    'family': 'melody'},
#   'MELODY60_STEP1': {'ema_score': 0.9925, 'family': 'melody'},
#   'MELODY60_STEP2': {'ema_score': 0.9924999999999999, 'family': 'melody'}},
#  'adaptive_drill_scores': [0.9925, 0.9924999999999999, None],
#  'adaptive_level_current': 111,
#  'adaptive_level_suggested': 112,
#  'adaptive_level_track': 'melody_levels',
#  'adaptive_level_up': True,
#  'adaptive_level_up_threshold': 0.8,
#  'avg_rt_ms': 1200,
#  'correct': 5,
#  'incorrect': 0}

# %%
result
# Out:
# {'session_id': 'sess-1',
#  'timeline': ['q-001', 'q-002', 'q-003', 'q-004', 'q-005'],
#  'summary': SessionSummary(session_id='sess-1', totals={'adaptive_bout_score': 0.9924999999999999, 'adaptive_drill_score_map': {'MELODY60': {'ema_score': None, 'family': 'melody'}, 'MELODY60_STEP1': {'ema_score': 0.9925, 'family': 'melody'}, 'MELODY60_STEP2': {'ema_score': 0.9924999999999999, 'family': 'melody'}}, 'adaptive_drill_scores': [0.9925, 0.9924999999999999, None], 'adaptive_level_current': 111, 'adaptive_level_suggested': 112, 'adaptive_level_track': 'melody_levels', 'adaptive_level_up': True, 'adaptive_level_up_threshold': 0.8, 'avg_rt_ms': 1200, 'correct': 5, 'incorrect': 0}, by_category=[{'label': 'adaptive', 'score': 1.0}], results=[{'correct': True, 'question_id': 'q-001', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-002', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-003', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-004', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-005', 'rt_ms': 1200, 'score': 1.0}]),
#  'memory': MemoryPackage(summary=SessionSummary(session_id='sess-1', totals={'adaptive_bout_score': 0.9924999999999999, 'adaptive_drill_score_map': {'MELODY60': {'ema_score': None, 'family': 'melody'}, 'MELODY60_STEP1': {'ema_score': 0.9925, 'family': 'melody'}, 'MELODY60_STEP2': {'ema_score': 0.9924999999999999, 'family': 'melody'}}, 'adaptive_drill_scores': [0.9925, 0.9924999999999999, None], 'adaptive_level_current': 111, 'adaptive_level_suggested': 112, 'adaptive_level_track': 'melody_levels', 'adaptive_level_up': True, 'adaptive_level_up_threshold': 0.8, 'avg_rt_ms': 1200, 'correct': 5, 'incorrect': 0}, by_category=[{'label': 'adaptive', 'score': 1.0}], results=[{'correct': True, 'question_id': 'q-001', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-002', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-003', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-004', 'rt_ms': 1200, 'score': 1.0}, {'correct': True, 'question_id': 'q-005', 'rt_ms': 1200, 'score': 1.0}]), adaptive=AdaptiveMemory(has_score=True, bout_average=0.9924999999999999, graduate_threshold=0.8, level_up=True, drills={'MELODY60': AdaptiveDrillMemory(family='melody', ema_score=None), 'MELODY60_STEP1': AdaptiveDrillMemory(family='melody', ema_score=0.9925), 'MELODY60_STEP2': AdaptiveDrillMemory(family='melody', ema_score=0.9924999999999999)}, level=AdaptiveLevelProposal(track_index=1, track_name='melody_levels', current_level=111, suggested_level=112))),
#  'diagnostics': {'bout_score_average': 0.9924999999999999,
#   'catalog_mode': 'builtin',
#   'current_track': 'melody_levels',
#   'drill_scores': [0.9925, 0.9924999999999999, None],
#   'families': ['melody', 'melody', 'melody'],
#   'ids': ['MELODY60_STEP1', 'MELODY60_STEP2', 'MELODY60'],
#   'last_pick': 0,
#   'last_track_pick': 1,
#   'level': 111,
#   'level_current': 111,
#   'level_suggested': 112,
#   'level_track_index': 1,
#   'level_track_name': 'melody_levels',
#   'level_up_ready': True,
#   'level_up_threshold': 0.8,
#   'phase_consistent': True,
#   'phase_digit': 1,
#   'pick_counts': [4, 1, 0],
#   'questions_emitted': 5,
#   'resources_dir': '/Users/itamarshamir/Projects/ear_trainer/eartrainer/eartrainer_Cpp/resources',
#   'slots': 3,
#   'track_levels': [11, 111],
#   'track_weights': [1, 3],
#   'tracks': [{'current_level': 11,
#     'levels_in_scope': [11],
#     'name': 'degree_levels',
#     'weight': 1},
#    {'current_level': 111,
#     'levels_in_scope': [111, 112, 113],
#     'name': 'melody_levels',
#     'weight': 3}]}}
